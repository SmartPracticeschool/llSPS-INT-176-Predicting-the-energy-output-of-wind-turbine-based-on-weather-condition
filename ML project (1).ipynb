# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("T1.csv")

# %%
data
# Out:
#               Date/Time  LV ActivePower (kW)  Wind Speed (m/s)  \
# 0      01 01 2018 00:00           380.047791          5.311336
# 1      01 01 2018 00:10           453.769196          5.672167
# 2      01 01 2018 00:20           306.376587          5.216037
# 3      01 01 2018 00:30           419.645905          5.659674
# 4      01 01 2018 00:40           380.650696          5.577941
# ...                 ...                  ...               ...
# 50525  31 12 2018 23:10          2963.980957         11.404030
# 50526  31 12 2018 23:20          1684.353027          7.332648
# 50527  31 12 2018 23:30          2201.106934          8.435358
# 50528  31 12 2018 23:40          2515.694092          9.421366
# 50529  31 12 2018 23:50          2820.466064          9.979332
#
#        Theoretical_Power_Curve (KWh)  Wind Direction (°)
# 0                         416.328908          259.994904
# 1                         519.917511          268.641113
# ...

# %%
data.drop('Date/Time',axis=1,inplace=True)
data
# Out:
#        LV ActivePower (kW)  Wind Speed (m/s)  Theoretical_Power_Curve (KWh)  \
# 0               380.047791          5.311336                     416.328908
# 1               453.769196          5.672167                     519.917511
# 2               306.376587          5.216037                     390.900016
# 3               419.645905          5.659674                     516.127569
# 4               380.650696          5.577941                     491.702972
# ...                    ...               ...                            ...
# 50525          2963.980957         11.404030                    3397.190793
# 50526          1684.353027          7.332648                    1173.055771
# 50527          2201.106934          8.435358                    1788.284755
# 50528          2515.694092          9.421366                    2418.382503
# 50529          2820.466064          9.979332                    2779.184096
#
#        Wind Direction (°)
# 0              259.994904
# ...

# %%
data.corr()
# Out:
#                                LV ActivePower (kW)  Wind Speed (m/s)  \
# LV ActivePower (kW)                       1.000000          0.912774
# Wind Speed (m/s)                          0.912774          1.000000
# Theoretical_Power_Curve (KWh)             0.949918          0.944209
# Wind Direction (°)                       -0.062702         -0.077188
#
#                                Theoretical_Power_Curve (KWh)  \
# LV ActivePower (kW)                                 0.949918
# Wind Speed (m/s)                                    0.944209
# Theoretical_Power_Curve (KWh)                       1.000000
# Wind Direction (°)                                 -0.099076
#
#                                Wind Direction (°)
# LV ActivePower (kW)                     -0.062702
# Wind Speed (m/s)                        -0.077188
# Theoretical_Power_Curve (KWh)           -0.099076
# Wind Direction (°)                       1.000000

# %%
#heatmap
import seaborn as sns
sns.heatmap(data.corr())

# %%
#scatter plot
plt.scatter(data['Wind Direction (°)'],data['LV ActivePower (kW)'])
plt.title("Numerical Feature: LV ActivePower v/s wind direction")
plt.xlabel("Wind Direction (°)")
plt.ylabel("LV ActivePower")
# Out:
# Text(0, 0.5, 'LV ActivePower')

# %%
plt.scatter(data['Wind Speed (m/s)'],data['LV ActivePower (kW)'],color='y')
plt.title("Numerical Feature:  LV Active power  v/s windspeed")
plt.xlabel("windspeed")
plt.ylabel("LV ActivePower")
# Out:
# Text(0, 0.5, 'LV ActivePower')

# %%
plt.scatter(data['Theoretical_Power_Curve (KWh)'],data['LV ActivePower (kW)'],color='r')
plt.title("Numerical Feature:  LV ActivePower(KW) v/s Theoretical_power")
plt.xlabel("Theoretical power")
plt.ylabel("LV ActivePower ")
# Out:
# Text(0, 0.5, 'LV ActivePower ')

# %% [raw]
# as we can see both the feature 'LV ActivePower (kW)' and 'Theoretical_Power_Curve (KWh)' have similar distribution and may present redundancy and even multicollinearity. to keep things clean we can drop the 'LV ActivePower (kW)' feature

# %%
#joint plot
sns.jointplot(data['Theoretical_Power_Curve (KWh)'],data['LV ActivePower (kW)'])

# %%
sns.jointplot(data['Wind Speed (m/s)'],data['LV ActivePower (kW)'], height=6, ratio=5, space=0.2)

# %%
sns.jointplot(data['Wind Direction (°)'],data['LV ActivePower (kW)'])

# %%
#line plots
plt.plot(data['Wind Direction (°)'],data['LV ActivePower (kW)'],'g')
plt.xlabel("energy of wind direction")
plt.ylabel("LV ActivePower")
# Out:
# Text(0, 0.5, 'LV ActivePower')

# %%
plt.plot(data['Wind Speed (m/s)'],data['LV ActivePower (kW)'],'r')
plt.xlabel("wind speed")
plt.ylabel("LV ActivePower")
# Out:
# Text(0, 0.5, 'LV ActivePower')

# %%
plt.plot(data['Theoretical_Power_Curve (KWh)'],data['LV ActivePower (kW)'])
plt.xlabel("Theoretical power")
plt.ylabel("LV ActivePower")
# Out:
# Text(0, 0.5, 'LV ActivePower')

# %%
#taking care of missing data
data.isnull().any()
# Out:
# LV ActivePower (kW)              False
# Wind Speed (m/s)                 False
# Theoretical_Power_Curve (KWh)    False
# Wind Direction (°)               False
# dtype: bool

# %% [raw]
# no missing data

# %%
#separating dependent and independent variables

# %%
x=data.iloc[0:,1:4].values
x
# Out:
# array([[   5.31133604,  416.32890782,  259.99490356],
#        [   5.67216682,  519.91751106,  268.64111328],
#        [   5.2160368 ,  390.90001581,  272.56478882],
#        ...,
#        [   8.43535805, 1788.28475526,   84.74250031],
#        [   9.42136574, 2418.38250336,   84.2979126 ],
#        [   9.97933197, 2779.18409628,   82.27462006]])

# %%
y=data.iloc[0:,0].values
y
# Out:
# array([ 380.04779053,  453.76919556,  306.37658691, ..., 2201.10693359,
#        2515.6940918 , 2820.46606445])

# %%
#label encoding and # onehot encoding

# %% [raw]
# as there are no categorical coloumns..there is no need to do label encoding and one hot encoding

# %%
#feature scaling
from sklearn.preprocessing import MinMaxScaler
m=MinMaxScaler()
x=m.fit_transform(x)
print("after minmax scaling")
x
# Out:
# after minmax scaling
# array([[0.21071704, 0.11564692, 0.7222129 ],
#        [0.22503231, 0.14442153, 0.74623031],
#        [0.20693623, 0.10858334, 0.75712948],
#        ...,
#        [0.33465661, 0.49674577, 0.23539741],
#        [0.37377457, 0.67177292, 0.23416244],
#        [0.3959108 , 0.77199558, 0.22854214]])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
print("after standard scaling")
x
# Out:
# after standard scaling
# array([[-0.53147626, -0.78643484,  1.45872479],
#        [-0.44611545, -0.71071243,  1.55125422],
#        [-0.55402096, -0.80502315,  1.59324434],
#        ...,
#        [ 0.20756566,  0.21645342, -0.41677961],
#        [ 0.44082298,  0.6770496 , -0.42153747],
#        [ 0.57281963,  0.94079255, -0.4431902 ]])

# %%
#splitting train and test data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
# array([[-0.47288274, -0.73540436, -0.61104065],
#        [-0.06308839, -0.24816052, -1.04615108],
#        [-0.9628355 , -1.05373613,  0.52784729],
#        ...,
#        [ 0.86012323,  1.34830253, -0.63432838],
#        [-0.26492175, -0.5191411 , -0.54217731],
#        [ 1.64957022,  1.54080212,  0.90420909]])

# %%
y_train
# Out:
# array([ 480.99530029, 1396.22802734,    0.        , ..., 3031.63598633,
#         730.65008545, 3604.44897461])

# %%
x_test
# Out:
# array([[-0.37979868, -0.64553433, -0.53946612],
#        [ 0.13649137,  0.08479787, -0.70790443],
#        [ 0.15357082,  0.11590876,  1.3998277 ],
#        ...,
#        [-0.30258141, -0.56285435,  0.01071719],
#        [ 1.07195273,  1.49339634, -1.00636365],
#        [ 0.65199822,  1.0820305 , -0.67888882]])

# %%
y_test
# Out:
# array([ 576.65698242, 1619.30102539, 1876.58105469, ...,  667.25708008,
#        3473.52294922, 2343.06396484])

# %% [raw]
# #model building

# %%
plt.scatter(x[:,1],y)

# %%
plt.scatter(x[:,2],y)

# %%
plt.scatter(x[:,0],y)

# %% [raw]
# from above observations multilinear fits this dataset..as the column contains continues values

# %%
from sklearn.linear_model import LinearRegression
mr=LinearRegression()
mr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred=mr.predict(x_test)

# %%
y_pred
# Out:
# array([ 522.55983991, 1396.51259912, 1516.33737283, ...,  647.52868071,
#        3071.75478983, 2564.26477776])

# %%
y_test
# Out:
# array([ 576.65698242, 1619.30102539, 1876.58105469, ...,  667.25708008,
#        3473.52294922, 2343.06396484])

# %%
#model evaluation
from sklearn.metrics import r2_score
r2_score(y_pred,y_test)
# Out:
# 0.8959631594498164
